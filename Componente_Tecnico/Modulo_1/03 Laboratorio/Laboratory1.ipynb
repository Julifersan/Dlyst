# %% [markdown]
# # **Laboratorio 1**

# %%
import pandas as pd
import matplotlib.pyplot as plt
import pygwalker as pyg
import seaborn as sns

# %% [markdown]
# **Se establece la ruta de la data y se  da un vistazo**

# %%
# Se almacena la ruta del archivo en la variable "archivo"
archivo = r"dataset_banco.csv"

# Se crea el dataframe 'banco'
banco = pd.read_csv(archivo, sep = ',')

# Se imprime el resultado ⬇️
banco
# Out:
#        age           job   marital  education default  balance housing loan  \
# 0       58    management   married   tertiary      no   2143.0     yes   no
# 1       44    technician    single  secondary      no     29.0     yes   no
# 2       33  entrepreneur   married  secondary      no      2.0     yes  yes
# 3       47   blue-collar   married    unknown      no   1506.0     yes   no
# 4       33       unknown    single    unknown      no      1.0      no   no
# ...    ...           ...       ...        ...     ...      ...     ...  ...
# 45210   51    technician   married   tertiary      no    825.0      no   no
# 45211   71       retired  divorced    primary      no   1729.0      no   no
# 45212   72       retired   married  secondary      no   5715.0      no   no
# 45213   57   blue-collar   married  secondary      no    668.0      no   no
# 45214   37  entrepreneur   married  secondary      no   2971.0      no   no
#
# ...

# %% [markdown]
# **Visualización y exploración de datos**

# %%
banco.head(4)
# Out:
#    age           job  marital  education default  balance housing loan  \
# 0   58    management  married   tertiary      no   2143.0     yes   no
# 1   44    technician   single  secondary      no     29.0     yes   no
# 2   33  entrepreneur  married  secondary      no      2.0     yes  yes
# 3   47   blue-collar  married    unknown      no   1506.0     yes   no
#
#    contact  day month  duration  campaign  pdays  previous poutcome   y
# 0  unknown    5   may     261.0         1   -1.0         0  unknown  no
# 1  unknown    5   may     151.0         1   -1.0         0  unknown  no
# 2  unknown    5   may      76.0         1   -1.0         0  unknown  no
# 3  unknown    5   may      92.0         1   -1.0         0  unknown  no

# %%
banco.tail(4)
# Out:
#        age           job   marital  education default  balance housing loan  \
# 45211   71       retired  divorced    primary      no   1729.0      no   no
# 45212   72       retired   married  secondary      no   5715.0      no   no
# 45213   57   blue-collar   married  secondary      no    668.0      no   no
# 45214   37  entrepreneur   married  secondary      no   2971.0      no   no
#
#          contact  day month  duration  campaign  pdays  previous poutcome    y
# 45211   cellular   17   nov     456.0         2   -1.0         0  unknown  yes
# 45212   cellular   17   nov    1127.0         5  184.0         3  success  yes
# 45213  telephone   17   nov     508.0         4   -1.0         0  unknown   no
# 45214   cellular   17   nov     361.0         2  188.0        11    other   no

# %%
banco.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 45215 entries, 0 to 45214
# Data columns (total 17 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   age        45215 non-null  int64
#  1   job        45213 non-null  object
#  2   marital    45214 non-null  object
#  3   education  45214 non-null  object
#  4   default    45215 non-null  object
#  5   balance    45213 non-null  float64
#  6   housing    45215 non-null  object
#  7   loan       45215 non-null  object
#  8   contact    45215 non-null  object
#  9   day        45215 non-null  int64
#  10  month      45215 non-null  object
#  11  duration   45214 non-null  float64
#  12  campaign   45215 non-null  int64
#  13  pdays      45214 non-null  float64
#  14  previous   45215 non-null  int64
#  15  poutcome   45215 non-null  object
#  16  y          45215 non-null  object
# dtypes: float64(3), int64(4), object(10)
# memory usage: 5.9+ MB

# %%
banco.describe()
# Out:
#                 age        balance           day      duration      campaign  \
# count  45215.000000   45213.000000  45215.000000  45214.000000  45215.000000
# mean      41.004711    1374.159866     15.805839    258.074357      2.763729
# std       12.036647    3924.255525      8.322473    257.605175      3.097910
# min       18.000000   -8019.000000      1.000000  -1389.000000      1.000000
# 25%       33.000000      72.000000      8.000000    103.000000      1.000000
# 50%       39.000000     448.000000     16.000000    180.000000      2.000000
# 75%       48.000000    1428.000000     21.000000    319.000000      3.000000
# max      776.000000  527532.000000     31.000000   4918.000000     63.000000
#
#               pdays      previous
# count  45214.000000  45215.000000
# mean      40.192485      0.580383
# std      100.120622      2.303438
# min       -1.000000      0.000000
# 25%       -1.000000      0.000000
# 50%       -1.000000      0.000000
# ...

# %%
banco.shape
# Out:
# (45215, 17)

# %%
banco.columns
# Out:
# Index(['age', 'job', 'marital', 'education', 'default', 'balance', 'housing',
#        'loan', 'contact', 'day', 'month', 'duration', 'campaign', 'pdays',
#        'previous', 'poutcome', 'y'],
#       dtype='object')

# %% [markdown]
# **Transformación de nombres de atributos**

# %%
#Muestra los atributos por defecto
banco.columns
# Out:
# Index(['age', 'job', 'marital', 'education', 'default', 'balance', 'housing',
#        'loan', 'contact', 'day', 'month', 'duration', 'campaign', 'pdays',
#        'previous', 'poutcome', 'y'],
#       dtype='object')

# %%
# Sustituir nombres los nombres de los atributos

# banco1 : Cambiar nombres atributos banco
banco1 = banco.rename(columns={
    "age":             'edad',
    "job":             'trabajo',
    'marital':        'estado_civil',
    'education':   'educacion',
    'default':        'morosidad',
    'balance':       'saldo',
    'housing':       'vivienda',
    'loan':             'prestamo',
    'contact':       'contacto',
    'day':              'dia',
    'month':        'mes',
    'duration':    'duracion',
    'campaign':  'campana',
    'pdays':         'dias_previos',
    'previous':    'anterior',
    'poutcome': 'resultado',
    'y':                 'respuesta'
})

banco1.columns
# Out:
# Index(['edad', 'trabajo', 'estado_civil', 'educacion', 'morosidad', 'saldo',
#        'vivienda', 'prestamo', 'contacto', 'dia', 'mes', 'duracion', 'campana',
#        'dias_previos', 'anterior', 'resultado', 'respuesta'],
#       dtype='object')

# %% [markdown]
# **Visualización de las primeras filas**

# %%
# Visualizar primeras filas, utilizo el .T para poder ver de mejor manera los atributos, siendo las columnas en vertical y los registros en horizontal, con el fin de mejorar los espacios y la visualización
banco1.head(4)
# Out:
#    edad       trabajo estado_civil  educacion morosidad   saldo vivienda  \
# 0    58    management      married   tertiary        no  2143.0      yes
# 1    44    technician       single  secondary        no    29.0      yes
# 2    33  entrepreneur      married  secondary        no     2.0      yes
# 3    47   blue-collar      married    unknown        no  1506.0      yes
#
#   prestamo contacto  dia  mes  duracion  campana  dias_previos  anterior  \
# 0       no  unknown    5  may     261.0        1          -1.0         0
# 1       no  unknown    5  may     151.0        1          -1.0         0
# 2      yes  unknown    5  may      76.0        1          -1.0         0
# 3       no  unknown    5  may      92.0        1          -1.0         0
#
#   resultado respuesta
# 0   unknown        no
# 1   unknown        no
# 2   unknown        no
# 3   unknown        no

# %% [markdown]
# **Variables categóricas y númericas**

# %%
# Se establece con .info, la informacion del tipo de dato de cada attributo, es solo para verificar
banco1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 45215 entries, 0 to 45214
# Data columns (total 17 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   edad          45215 non-null  int64
#  1   trabajo       45213 non-null  object
#  2   estado_civil  45214 non-null  object
#  3   educacion     45214 non-null  object
#  4   morosidad     45215 non-null  object
#  5   saldo         45213 non-null  float64
#  6   vivienda      45215 non-null  object
#  7   prestamo      45215 non-null  object
#  8   contacto      45215 non-null  object
#  9   dia           45215 non-null  int64
#  10  mes           45215 non-null  object
#  11  duracion      45214 non-null  float64
#  12  campana       45215 non-null  int64
#  13  dias_previos  45214 non-null  float64
#  14  anterior      45215 non-null  int64
#  15  resultado     45215 non-null  object
#  16  respuesta     45215 non-null  object
# dtypes: float64(3), int64(4), object(10)
# ...

# %%
# banco1Categoricas: son las variables con texto (object).
# banco1Numericas = será un nuevo dataframe que contiene solo los atributos categóricos.
# .select_dtypes(include=["object"]) : Selecciona todas las columnas del dataFrame 'banco1' que son de tipo 'object y almacena el resultado en 'banco1Categoricas.
banco1Categoricas = banco1.select_dtypes(include=["object"])

# Se muestran los atributos de tipo categórico
banco1Categoricas.columns
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 45215 entries, 0 to 45214
# Data columns (total 10 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   trabajo       45213 non-null  object
#  1   estado_civil  45214 non-null  object
#  2   educacion     45214 non-null  object
#  3   morosidad     45215 non-null  object
#  4   vivienda      45215 non-null  object
#  5   prestamo      45215 non-null  object
#  6   contacto      45215 non-null  object
#  7   mes           45215 non-null  object
#  8   resultado     45215 non-null  object
#  9   respuesta     45215 non-null  object
# dtypes: object(10)
# memory usage: 3.4+ MB

# %%
# Se verifica el tipo de datos que existen en las columnas que seleccionamos como categóricas
banco1Categoricas.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 45215 entries, 0 to 45214
# Data columns (total 10 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   trabajo       45213 non-null  object
#  1   estado_civil  45214 non-null  object
#  2   educacion     45214 non-null  object
#  3   morosidad     45215 non-null  object
#  4   vivienda      45215 non-null  object
#  5   prestamo      45215 non-null  object
#  6   contacto      45215 non-null  object
#  7   mes           45215 non-null  object
#  8   resultado     45215 non-null  object
#  9   respuesta     45215 non-null  object
# dtypes: object(10)
# memory usage: 3.4+ MB

# %%
 # banco1Numericas : Representaran a los atributos numericos, tanto int, como float
 # La explicación es similar, solo que en el caso de numericas
banco1Numericas = banco1.select_dtypes(include=["int64",'float64' ])
banco1Numericas.columns
# Out:
# Index(['edad', 'saldo', 'dia', 'duracion', 'campana', 'dias_previos',
#        'anterior'],
#       dtype='object')

# %%
banco1Numericas.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 45215 entries, 0 to 45214
# Data columns (total 7 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   edad          45215 non-null  int64
#  1   saldo         45213 non-null  float64
#  2   dia           45215 non-null  int64
#  3   duracion      45214 non-null  float64
#  4   campana       45215 non-null  int64
#  5   dias_previos  45214 non-null  float64
#  6   anterior      45215 non-null  int64
# dtypes: float64(3), int64(4)
# memory usage: 2.4 MB

# %% [markdown]
# **Identificar la frecuencia de los subniveles del atributo job o trabajo.**

# %%
# Identificar los nombres de cada registro del atributo 'trabajo' y los enumera según su numero de ocurrencia
frecuenciaTrabajo = pd.value_counts(banco1["trabajo"])

frecuenciaTrabajo
# Out:
# C:\Users\Usuario\AppData\Local\Temp\ipykernel_21572\903846399.py:2: FutureWarning: pandas.value_counts is deprecated and will be removed in a future version. Use pd.Series(obj).value_counts() instead.
#   frecuenciaTrabajo = pd.value_counts(banco1["trabajo"])
# trabajo
# blue-collar       9731
# management        9455
# technician        7599
# admin.            5168
# services          4153
# retired           2263
# self-employed     1578
# entrepreneur      1487
# unemployed        1303
# housemaid         1240
# student            938
# unknown            288
# administrative       3
# Management           2
# MANAGEMENT           2
# Self-employed        1
# Services             1
# Retired              1
# Name: count, dtype: int64

# %% [markdown]
# **Seguimos identificando las demás frecuencias de todas las variables categóricas**
#
# Esto se hace con el fin de identificar los subniveles y sus relevancias, así como valores o registros duplicados pero con nombre diferente.

# %%
frecuenciaEstadocivil = pd.value_counts(banco1["estado_civil"])


frecuenciaEstadocivil
# Out:
# C:\Users\Usuario\AppData\Local\Temp\ipykernel_21572\2731207813.py:1: FutureWarning: pandas.value_counts is deprecated and will be removed in a future version. Use pd.Series(obj).value_counts() instead.
#   frecuenciaEstadocivil = pd.value_counts(banco1["estado_civil"])
# estado_civil
# married     27215
# single      12787
# divorced     5198
# div.            7
# Single          4
# DIVORCED        3
# Name: count, dtype: int64

# %%
frecuenciaEducación = pd.value_counts(banco1["educacion"])

frecuenciaEducación
# Out:
# C:\Users\Usuario\AppData\Local\Temp\ipykernel_21572\4003994840.py:1: FutureWarning: pandas.value_counts is deprecated and will be removed in a future version. Use pd.Series(obj).value_counts() instead.
#   frecuenciaEducación = pd.value_counts(banco1["educacion"])
# educacion
# secondary    23197
# tertiary     13302
# primary       6849
# unknown       1855
# SECONDARY        3
# Primary          2
# sec.             2
# UNK              2
# Secondary        1
# Tertiary         1
# Name: count, dtype: int64

# %%
frecuenciaMorosidad = pd.value_counts(banco1['morosidad'])

frecuenciaMorosidad
# Out:
# C:\Users\Usuario\AppData\Local\Temp\ipykernel_21572\1038526890.py:1: FutureWarning: pandas.value_counts is deprecated and will be removed in a future version. Use pd.Series(obj).value_counts() instead.
#   frecuenciaMorosidad = pd.value_counts(banco1['morosidad'])
# morosidad
# no     44399
# yes      816
# Name: count, dtype: int64

# %%
frecuenciaVivienda = pd.value_counts(banco1['vivienda'])

frecuenciaVivienda
# Out:
# C:\Users\Usuario\AppData\Local\Temp\ipykernel_21572\3254790190.py:1: FutureWarning: pandas.value_counts is deprecated and will be removed in a future version. Use pd.Series(obj).value_counts() instead.
#   frecuenciaVivienda = pd.value_counts(banco1['vivienda'])
# vivienda
# yes    25132
# no     20083
# Name: count, dtype: int64

# %%
frecuenciaPrestamo = pd.value_counts(banco1['prestamo'])

frecuenciaPrestamo
# Out:
# C:\Users\Usuario\AppData\Local\Temp\ipykernel_21572\689550967.py:1: FutureWarning: pandas.value_counts is deprecated and will be removed in a future version. Use pd.Series(obj).value_counts() instead.
#   frecuenciaPrestamo = pd.value_counts(banco1['prestamo'])
# prestamo
# no     37962
# yes     7243
# No         5
# YES        2
# NO         2
# Yes        1
# Name: count, dtype: int64

# %%
frecuenciaContacto = pd.value_counts(banco1['contacto'])

frecuenciaContacto
# Out:
# C:\Users\Usuario\AppData\Local\Temp\ipykernel_21572\403064089.py:1: FutureWarning: pandas.value_counts is deprecated and will be removed in a future version. Use pd.Series(obj).value_counts() instead.
#   frecuenciaContacto = pd.value_counts(banco1['contacto'])
# contacto
# cellular     29285
# unknown      13021
# telephone     2903
# phone            3
# mobile           3
# Name: count, dtype: int64

# %%
frecuenciaMes = pd.value_counts(banco1['mes'])

frecuenciaMes
# Out:
# C:\Users\Usuario\AppData\Local\Temp\ipykernel_21572\2009217787.py:1: FutureWarning: pandas.value_counts is deprecated and will be removed in a future version. Use pd.Series(obj).value_counts() instead.
#   frecuenciaMes = pd.value_counts(banco1['mes'])
# mes
# may    13768
# jul     6895
# aug     6247
# jun     5342
# nov     3971
# apr     2932
# feb     2649
# jan     1403
# oct      738
# sep      579
# mar      477
# dec      214
# Name: count, dtype: int64

# %%
frecuenciaResultado = pd.value_counts(banco1['resultado'])

frecuenciaResultado
# Out:
# C:\Users\Usuario\AppData\Local\Temp\ipykernel_21572\1748728265.py:1: FutureWarning: pandas.value_counts is deprecated and will be removed in a future version. Use pd.Series(obj).value_counts() instead.
#   frecuenciaResultado = pd.value_counts(banco1['resultado'])
# resultado
# unknown    36958
# failure     4902
# other       1840
# success     1509
# UNK            4
# Success        2
# Name: count, dtype: int64

# %%
frecuenciaRespuesta = pd.value_counts(banco1['respuesta'])

frecuenciaRespuesta
# Out:
# C:\Users\Usuario\AppData\Local\Temp\ipykernel_21572\3181684395.py:1: FutureWarning: pandas.value_counts is deprecated and will be removed in a future version. Use pd.Series(obj).value_counts() instead.
#   frecuenciaRespuesta = pd.value_counts(banco1['respuesta'])
# respuesta
# no     39925
# yes     5290
# Name: count, dtype: int64

# %% [markdown]
# ## **Limpieza de datos**
#
# Se realizará el proceso de limpieza teniendo en cuenta las situaciones más comunes.
#
# 1. Datos faltantes en algunas celdas.
# 2. Columnas irrelevantes (Teniendo en cuenta las pregntas de negocio o problemas que queremos solventar).
# 3. Registros (filas) repetidas, duplicados.
# 4. Valores extremos (Outliers), esto en el caso de las variables o atributos númericos.
#     * Se deben analizar bien, ya que esos valores podrían represntar algun valor realmente importante, o en su defecto, un error de tipeo o registro del mismo.
# 5. Errores tipográficos en el caso de las variables categóricas.
#
# Al culminar estos procesos, se deberían tener en práctica, unos datos totalmente integros, listos para la fase del análisis exploratorio.

# %% [markdown]
# ### **Limpieza de datos: Datos faltantes**
#
# En este punto, se visualizará los datos que no están completos, puesto que no todas los atributos tienen la misma cantidad de registros en sus subniveles o celdas.
#
# EL número total de registros debería ser para todos el mismo número, no obstante, algunos atributos podrían contener ese tipo de errores.

# %%
# .isna(): Es un método de pandas usado para contar los valores faltantes, teniendo en cuenta que se cuenta segun True y False, con valores de 1 y 0 respectivamente.
# sum(): Usado para sumar los valores 0 y 1

banco1.isna().sum()
# Out:
# edad            0
# trabajo         2
# estado_civil    1
# educacion       1
# morosidad       0
# saldo           2
# vivienda        0
# prestamo        0
# contacto        0
# dia             0
# mes             0
# duracion        1
# campana         0
# dias_previos    1
# anterior        0
# resultado       0
# respuesta       0
# dtype: int64

# %% [markdown]
# Los datos faltantes pertenecen a los atributos 'trabajo', 'estado_civil', 'educacion', 'saldo', 'duracion', 'dias_previos'.
#
# Al ser tán pocos comparados con el numero de filas de la data, se optará por eliminarlos.

# %%
# Se establece un nuevo dataframe para que sea este el que será modificado, esto para fines prácticos y llevar una secuencialidad
banco2 = banco1.copy()# Uso .copy, para asegurarme de que banco2 sea una copia independiente de banco1

# .dropna(inplace=True): Este médotod lo que hace es eliminar todas las filas que contengan en sus celdas valores faltantes NaN.
    # inplace=True: Lo que indíca es que el dataframe, quedará modificado directamente a partir del proceso y no se devolvera una copia
     # inplace=False : Se dejará en False para que la variable se convierta en el nuevo DataFrame y no se modifique el original
banco2.dropna(inplace=True)

# Visualización y verificación del  dataframe sin valores faltantes
banco2.isna().sum()
# Out:
# edad            0
# trabajo         0
# estado_civil    0
# educacion       0
# morosidad       0
# saldo           0
# vivienda        0
# prestamo        0
# contacto        0
# dia             0
# mes             0
# duracion        0
# campana         0
# dias_previos    0
# anterior        0
# resultado       0
# respuesta       0
# dtype: int64

# %%
# Verificación de dataset banco1, el cual es un dataset ya depurado
banco1.count()
# Out:
# edad            45215
# trabajo         45213
# estado_civil    45214
# educacion       45214
# morosidad       45215
# saldo           45213
# vivienda        45215
# prestamo        45215
# contacto        45215
# dia             45215
# mes             45215
# duracion        45214
# campana         45215
# dias_previos    45214
# anterior        45215
# resultado       45215
# respuesta       45215
# dtype: int64

# %% [markdown]
# ### **Limieza de datos: Columnas irrelevantes**
#
# > Para darle contexto
#
# Una columna irrelevante podría ser:
#
# * **Una columna que no contiene informacion relevante para el problema que queremos resolver.**
#
# * **Una columna categórica pero con un solo nivel:** Un ejemplo tácito para el atributo trabajo, que esté solo contuviera subniveles de un solo valor, ya sea unknown, employed, u otra categoría, pero que solo sea uno solo representando el atributo en su concepto general.
#
# * **Una columna númerica con un solo valor constante:** Algo similar al ejemplo anterior de la columna categórica.
#
# * **Columnas con información redundante:** Esto se ve comunmente en la columna de fechas, en la cual, a veces tenemos una columna que da la fecha completa, y otras en las cuales dice solo el año u otra que diga el mes, teniendo redundancia o exceso de los misma información, por lo que sería datos irrelevantes.

# %%
# Conteo de los atributos en las diferentes columnas categóricas
ome = ['trabajo', 'estado_civil', 'educacion', 'morosidad', 'vivienda',
       'prestamo', 'contacto', 'mes', 'resultado', 'respuesta' ]

for atributo in ome:
    print(f"El atributo o columna {atributo}, tiene {banco1Categoricas[atributo].nunique()} subniveles en sus registros")
# Out:
# El atributo o columna trabajo, tiene 18 subniveles en sus registros
# El atributo o columna estado_civil, tiene 6 subniveles en sus registros
# El atributo o columna educacion, tiene 10 subniveles en sus registros
# El atributo o columna morosidad, tiene 2 subniveles en sus registros
# El atributo o columna vivienda, tiene 2 subniveles en sus registros
# El atributo o columna prestamo, tiene 6 subniveles en sus registros
# El atributo o columna contacto, tiene 5 subniveles en sus registros
# El atributo o columna mes, tiene 12 subniveles en sus registros
# El atributo o columna resultado, tiene 6 subniveles en sus registros
# El atributo o columna respuesta, tiene 2 subniveles en sus registros

# %% [markdown]
# Se visualiza las frecuencias de los atributos númericos

# %%
frecuenciaEdad = pd.Series(banco1Numericas['edad']).value_counts()

frecuenciaEdad
# Out:
# edad
# 32     2084
# 31     1995
# 33     1972
# 34     1930
# 35     1894
#        ...
# 399       1
# 311       1
# 776       1
# 332       1
# 490       1
# Name: count, Length: 85, dtype: int64

# %%
frecuenciaSaldo = pd.Series(banco1Numericas['saldo']).value_counts()

frecuenciaSaldo
# Out:
# saldo
#  0.0        3514
#  1.0         195
#  2.0         156
#  4.0         139
#  3.0         134
#             ...
# -381.0         1
#  4617.0        1
#  20584.0       1
#  4358.0        1
#  16353.0       1
# Name: count, Length: 7168, dtype: int64

# %%
frecuenciaDia = pd.Series(banco1Numericas['dia']).value_counts()

frecuenciaDia
# Out:
# dia
# 20    2752
# 18    2308
# 21    2026
# 17    1939
# 6     1932
# 5     1910
# 14    1848
# 8     1843
# 28    1830
# 7     1817
# 19    1757
# 29    1745
# 15    1703
# 12    1603
# 13    1585
# 30    1566
# 9     1561
# 11    1480
# 4     1445
# 16    1416
# 2     1294
# 27    1121
# 3     1079
# 26    1035
# 23     939
# 22     905
# 25     840
# 31     643
# 10     524
# 24     447
# 1      322
# Name: count, dtype: int64

# %%
frecuenciaDuracion = pd.Series(banco1Numericas['duracion']).value_counts()

frecuenciaDuracion
# Out:
# duracion
# 124.0     188
# 90.0      184
# 89.0      177
# 104.0     175
# 114.0     175
#          ...
# 1834.0      1
# 1597.0      1
# 1456.0      1
# 1471.0      1
# 1556.0      1
# Name: count, Length: 1575, dtype: int64

# %%
frecuenciaCampana = pd.Series(banco1Numericas['campana']).value_counts()

frecuenciaCampana
# Out:
# campana
# 1     17546
# 2     12507
# 3      5521
# 4      3522
# 5      1764
# 6      1291
# 7       735
# 8       540
# 9       327
# 10      266
# 11      201
# 12      155
# 13      133
# 14       93
# 15       84
# 16       79
# 17       69
# 18       51
# 19       44
# 20       43
# 21       35
# 22       23
# 25       22
# 23       22
# 24       20
# 29       16
# 28       16
# 26       13
# 31       12
# 27       10
# 32        9
# 30        8
# 33        6
# 34        5
# 36        4
# 35        4
# 43        3
# 38        3
# 37        2
# 50        2
# 41        2
# 46        1
# 58        1
# 55        1
# 63        1
# 51        1
# 39        1
# 44        1
# Name: count, dtype: int64

# %%
frecuenciaDias_previos = pd.Series(banco1Numericas['dias_previos']).value_counts()

frecuenciaDias_previos
# Out:
# dias_previos
# -1.0      36957
#  182.0      167
#  92.0       147
#  91.0       126
#  183.0      126
#           ...
#  449.0        1
#  452.0        1
#  648.0        1
#  595.0        1
#  530.0        1
# Name: count, Length: 559, dtype: int64

# %%
frecuenciaAnterior = pd.Series(banco1Numericas['anterior']).value_counts()

frecuenciaAnterior
# Out:
# anterior
# 0      36957
# 1       2772
# 2       2106
# 3       1142
# 4        714
# 5        460
# 6        277
# 7        205
# 8        129
# 9         92
# 10        67
# 11        65
# 12        44
# 13        38
# 15        20
# 14        19
# 17        15
# 16        13
# 19        11
# 20         8
# 23         8
# 18         6
# 22         6
# 24         5
# 27         5
# 21         4
# 29         4
# 25         4
# 30         3
# 38         2
# 37         2
# 26         2
# 28         2
# 51         1
# 275        1
# 58         1
# 32         1
# 40         1
# 55         1
# 35         1
# 41         1
# Name: count, dtype: int64

# %% [markdown]
# ## **Estadística**

# %%
# Desviacion Estándar de los atributos númericos
sNumericas = (banco1Numericas).std()

sNumericas
# Out:
# edad              12.036647
# saldo           3924.255525
# dia                8.322473
# duracion         257.605175
# campana            3.097910
# dias_previos     100.120622
# anterior           2.303438
# dtype: float64

# %% [markdown]
# # **Graficos con Matplotlib**
# * Crear una gráfica de barras para representar las desviaciones estándar de las columnas numericas

# %%
# Gráfico
sNumericas.plot(kind='bar')
plt.title('Desviacion estandar de los atributos numericos')
plt.xlabel('Atributos')
plt.ylabel('Desviacion Estándar')
plt.xticks(rotation= -45 )
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
# Gráficar la desviacion estandar de 'dias_previos'
sNumericas_Dias_previos  = banco1Numericas['dias_previos'].std()

plt.figure(figsize=(4,2)) # Tamaño de la figura
plt.bar('dias_previos', sNumericas_Dias_previos ) # Se crea una barra para la desviacion estandar
plt.title('Desviacion estandar de dias_previos')
plt.ylabel('Desviacion estandar')
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
mNumericas_Dias_previos = banco1Numericas['dias_previos'].mean()

mNumericas_Dias_previos
# Out:
# 40.19248462865484

# %%
# Graficar un histograma del atributo 'dias_previos'
plt.hist(banco1Numericas['dias_previos'], bins=20, color='skyblue', edgecolor='black')

# Agregar una línea vertical para mostrar la media
plt.axvline(mNumericas_Dias_previos, color='red', linestyle='dashed', linewidth=1)

# Etiquetas y título
plt.xlabel('Valor de los dias_previos')
plt.ylabel('Frecuencia')
plt.title('Histograma de la pdays con Media')

# Mostrar la gráfica
plt.show()

# %% [markdown]
# ### **Limpieza de datos: Filas repetidas**

# %%
#Mostramos la cantidad de registros antes de aplicar una transformación, limpieza o filtro
print(f'Tamaño del set antes de eliminar las filas repetidas: {banco2.shape}')

banco2.drop_duplicates(inplace=True)
#Mostramos la cantidad de registros después de aplicar una transformación, limpieza o filtro
print(f'Tamaño del set después de eliminar las filas repetidas: {banco2.shape}')
# Out:
# Tamaño del set antes de eliminar las filas repetidas: (45207, 17)
# Tamaño del set después de eliminar las filas repetidas: (45203, 17)

# %% [markdown]
# ### **Limpieza de datos: Outliers**

# %%
# Creamos un tipo de gráfico boxplot de las columnas númericas
#generar gráficas individuales para las variables númericas, ya que están en rangos diferentes.

fig, ax = plt.subplots(nrows=7, ncols=1, figsize=(8,30))
fig.subplots_adjust(hspace=0.5)

for i, col in enumerate(banco1Numericas):
    sns.boxplot(x=col, data=banco1Numericas, ax=ax[i])
    ax[i].set_title(col)

# %% [markdown]
# ## **Observaciones**
#
# * **"edad":** hay sujetos con edades mucho mayores a 100 años
# * **"duracion":** hay valores negativos
# * **"anterior":** hay un valor extremadamente alto (cercano a 300)

# %%
# Eliminar filas con "edad">100
print(f'Tamaño del set antes de eliminar registros de edad: {banco1Numericas.shape}')

banco1Numericas = banco1Numericas.drop(banco1Numericas[banco1Numericas['edad'] > 100].index)
print(f'Tamaño del set después de eliminar registros de edad: {banco1Numericas.shape}')
# Out:
# Tamaño del set antes de eliminar registros de edad: (45215, 7)
# Tamaño del set después de eliminar registros de edad: (45207, 7)

# %%
# Eliminar filas con "duracion"<0
print(f'Tamaño del set antes de eliminar registros de duración: {banco1Numericas.shape}')

banco1Numericas = banco1Numericas.drop(banco1Numericas[banco1Numericas['duracion'] < 0].index)

print(f'Tamaño del set después de eliminar registros de duración: {banco1Numericas.shape}')
# Out:
# Tamaño del set antes de eliminar registros de duración: (45207, 7)
# Tamaño del set después de eliminar registros de duración: (45205, 7)

# %%
# Eliminar filas con "dias_previos">100
print(f'Tamaño del set antes de eliminar registros de edad: {banco1Numericas.shape}')

banco1Numericas = banco1Numericas.drop(banco1Numericas[banco1Numericas['dias_previos'] > 100].index)

print(f'Tamaño del set después de eliminar registros de edad: {banco1Numericas.shape}')
# Out:
# Tamaño del set antes de eliminar registros de edad: (45205, 7)
# Tamaño del set después de eliminar registros de edad: (38386, 7)

# %% [markdown]
# ### **Limpieza de datos: Errores tipográficos en variables categóricas**
# En una variable categórica pueden aparecer sub-niveles como "unknown" y "UNK" que para nosotros son equivalentes pero que para nuestro programa parecerían diferentes.
#
# > Se deben unificar estos sub-niveles

# %%
# Graficar los subniveles de cada variable categórica
fig, ax = plt.subplots(nrows=10, ncols=1, figsize=(10,30))
fig.subplots_adjust(hspace=1)

for i, col in enumerate(banco1Categoricas):
  sns.countplot(x=col, hue=col, data=banco1Categoricas, ax=ax[i], palette= 'colorblind', legend=False)
  ax[i].set_title(col)
  ax[i].tick_params(axis='x', labelrotation=30)

# %% [markdown]
# Inicialmente se observa que hay sub-niveles con el mismo nombre pero escritos en minúscula, en mayúscula o con la primera letra en mayúscula.
#
# Unifiquemos estos sub-niveles inicialmente:

# %% [markdown]
# ## **Normalizar subniveles**

# %%
frecuenciaTrabajo
# Out:
# trabajo
# blue-collar       9731
# management        9455
# technician        7599
# admin.            5168
# services          4153
# retired           2263
# self-employed     1578
# entrepreneur      1487
# unemployed        1303
# housemaid         1240
# student            938
# unknown            288
# administrative       3
# Management           2
# MANAGEMENT           2
# Self-employed        1
# Services             1
# Retired              1
# Name: count, dtype: int64

# %%
# Unificar subniveles del atributo 'trabajo'
mappingTrabajo = {
    'management':                           'Gestion',
    'Management':                           'Gestion',
    'MANAGEMENT':                       'Gestion',
    'self-employed':                         'Independiente',
    'Self-employed':                         'Independiente',
    'technician':                                'Tecnico',
    'blue-collar':                                'Obrero',
    'admin.':                                      'Administrador',
    'administrative':                         'Administrador',
    'services':                                    'Servicio',
    'Services':                                    'Servicio',
    'retired':                                      'Jubilado',
    'Retired':                                     'Jubilado',
    'entrepreneur':                          'Emprendedor',
    'unemployed':                            'Desempleado',
    'housemaid':                               'Mucama',
    'student':                                     'Estudiante',
    'unknown':                                  'Desconocido',
    'Desconocido':                            'Desconocido'
}

# Reemplazar los valores según el diccionario de mapeo
banco1Categoricas['trabajo'] = banco1Categoricas['trabajo'].replace(mappingTrabajo)

frecuenciaTrabajoCLean = pd.Series(banco1Categoricas['trabajo']).value_counts()

frecuenciaTrabajoCLean
# Out:
# trabajo
# Obrero           9731
# Gestion          9459
# Tecnico          7599
# Administrador    5171
# Servicio         4154
# Jubilado         2264
# Independiente    1579
# Emprendedor      1487
# Desempleado      1303
# Mucama           1240
# Estudiante        938
# Desconocido       288
# Name: count, dtype: int64

# %%
banco1Categoricas.columns
# Out:
# Index(['trabajo', 'estado_civil', 'educacion', 'morosidad', 'vivienda',
#        'prestamo', 'contacto', 'mes', 'resultado', 'respuesta'],
#       dtype='object')

# %%
frecuenciaEstadocivil
# Out:
# estado_civil
# married     27215
# single      12787
# divorced     5198
# div.            7
# Single          4
# DIVORCED        3
# Name: count, dtype: int64

# %%
mappingEstadocivil = {
    'married':          'Casado',
    'single':              'Soltero',
    'Single':              'Soltero',
    'divorced':         'Divorciado',
    'div.':                  'Divorciado',
    'DIVORCED':     'Divorciado',
}

banco1Categoricas['estado_civil'] = banco1Categoricas['estado_civil'].replace(mappingEstadocivil)

frecuenciaEstadocivilClean = pd.Series(banco1Categoricas['estado_civil']).value_counts()

frecuenciaEstadocivilClean
# Out:
# estado_civil
# Casado        27215
# Soltero       12791
# Divorciado     5208
# Name: count, dtype: int64

# %%
frecuenciaEducación
# Out:
# educacion
# secondary    23197
# tertiary     13302
# primary       6849
# unknown       1855
# SECONDARY        3
# Primary          2
# sec.             2
# UNK              2
# Secondary        1
# Tertiary         1
# Name: count, dtype: int64

# %%
mappingEducacion = {
    'secondary':        'Secundaria',
    'SECONDARY':    'Secundaria',
    'sec.':                   'Secundaria',
    'Secondary':       'Secundaria',
    'tertiary':            'Terciaria',
    'Tertiary':            'Terciaria',
    'primary':           'Primaria',
    'Primary':           'Primaria',
    'unknown':        'Desconocido',
    'UNK':                 'Desconocido',
}

banco1Categoricas['educacion'] = banco1Categoricas['educacion'].replace(mappingEducacion)

frecuenciaEducacionClean = pd.Series(banco1Categoricas['educacion']).value_counts()

print(frecuenciaEducacionClean)
# Out:
# educacion
# Secundaria     23203
# Terciaria      13303
# Primaria        6851
# Desconocido     1857
# Name: count, dtype: int64

# %%
frecuenciaMorosidad
# Out:
# morosidad
# no     44399
# yes      816
# Name: count, dtype: int64

# %%
frecuenciaVivienda
# Out:
# vivienda
# yes    25132
# no     20083
# Name: count, dtype: int64

# %%
frecuenciaPrestamo
# Out:
# prestamo
# no     37962
# yes     7243
# No         5
# YES        2
# NO         2
# Yes        1
# Name: count, dtype: int64

# %%
mappingPrestamo = {
    'No' : 'no',
    'NO' : 'no',
    'Yes' : 'yes',
    'YES' : 'yes',
}

banco1Categoricas['prestamo'] = banco1Categoricas['prestamo'].replace(mappingPrestamo)

frecuenciaPrestamoClean = pd.Series(banco1Categoricas['prestamo']).value_counts()

frecuenciaPrestamoClean
# Out:
# prestamo
# no     37969
# yes     7246
# Name: count, dtype: int64

# %%
frecuenciaContacto
# Out:
# contacto
# cellular     29285
# unknown      13021
# telephone     2903
# phone            3
# mobile           3
# Name: count, dtype: int64

# %%
mappingContacto = {
    'cellular':       'Celular',
    'unknown':   'Desconocido',
    'telephone': 'Telefono',
    'phone':        'Telefono',
    'mobile':       'Celular',
}

banco1Categoricas['contacto'] = banco1Categoricas['contacto'].replace(mappingContacto)

frecuenciaContactoClean = pd.value_counts(banco1Categoricas['contacto'])

frecuenciaContactoClean
# Out:
# C:\Users\Usuario\AppData\Local\Temp\ipykernel_21572\993100716.py:11: FutureWarning: pandas.value_counts is deprecated and will be removed in a future version. Use pd.Series(obj).value_counts() instead.
#   frecuenciaContactoClean = pd.value_counts(banco1Categoricas['contacto'])
# contacto
# Celular        29288
# Desconocido    13021
# Telefono        2906
# Name: count, dtype: int64

# %%
frecuenciaMes
# Out:
# mes
# may    13768
# jul     6895
# aug     6247
# jun     5342
# nov     3971
# apr     2932
# feb     2649
# jan     1403
# oct      738
# sep      579
# mar      477
# dec      214
# Name: count, dtype: int64

# %%
frecuenciaResultado
# Out:
# resultado
# unknown    36958
# failure     4902
# other       1840
# success     1509
# UNK            4
# Success        2
# Name: count, dtype: int64

# %%
mappingResultado = {
    'unknown':'Desconocido',
    'UNK':'Desconocido',
    'failure':'Fallo',
    'other':'Otro',
    'success':'Exitoso',
    'Success':'Exitoso',
}

banco1Categoricas['resultado'] = banco1Categoricas['resultado'].replace(mappingResultado)

frecuenciaResultadoClean = pd.Series(banco1Categoricas['resultado']).value_counts()

frecuenciaResultadoClean
# Out:
# resultado
# Desconocido    36962
# Fallo           4902
# Otro            1840
# Exitoso         1511
# Name: count, dtype: int64

# %%
frecuenciaRespuesta
# Out:
# respuesta
# no     39925
# yes     5290
# Name: count, dtype: int64

# %%
fig, ax = plt.subplots(nrows=10, ncols=1, figsize=(10,30))
fig.subplots_adjust(hspace=1)

for i, col in enumerate(banco1Categoricas):
  sns.countplot(x=col, hue=col, data=banco1Categoricas, ax=ax[i], palette= 'colorblind', legend=False)
  ax[i].set_title(col)
  ax[i].tick_params(axis='x', labelrotation=30)

# %%
# Unir los dataframes limpios en uno solo
bancoClean = pd.concat([banco1Numericas, banco1Categoricas], axis=1)


bancoClean.columns
# Out:
# Index(['edad', 'saldo', 'dia', 'duracion', 'campana', 'dias_previos',
#        'anterior', 'trabajo', 'estado_civil', 'educacion', 'morosidad',
#        'vivienda', 'prestamo', 'contacto', 'mes', 'resultado', 'respuesta'],
#       dtype='object')

# %%
# Lectura de la data con la librería
pyg.walk(bancoClean)
# Out:
# Box(children=(HTML(value='\n<div id="ifr-pyg-000620819f1b6388g3M7QvwHVrUuF4ZJ" style="height: auto">\n    <hea…
# <script>
#     window.addEventListener("message", function(event) {
#         const backgroundMap = {
#             "dark": "hsl(240 10% 3.9%)",
#             "light": "hsl(0 0 100%)",
#         };
#         const colorMap = {
#             "dark": "hsl(0 0% 98%)",
#             "light": "hsl(240 10% 3.9%)",
#         };
#         if (event.data.action === "changeAppearance" && event.data.gid === "000620819f1b6388g3M7QvwHVrUuF4ZJ") {
#             var iframe = document.getElementById("gwalker-000620819f1b6388g3M7QvwHVrUuF4ZJ");
#             iframe.style.background  = backgroundMap[event.data.appearance];
#             iframe.style.color = colorMap[event.data.appearance];
#         }
#     });
# </script>

# %%
#Edad(age) promedio(mean) de los clientes interesados en adquirir un certificado de depósito(y)
edad_promedio_interesados = bancoClean[bancoClean['respuesta'] == 'yes']['edad'].mean()

print("1. Edad promedio de los clientes interesados:", edad_promedio_interesados)
# Out:
# 1. Edad promedio de los clientes interesados: 41.41023720349563

# %%
#Diferencia de ingresos entre clientes interesados y no interesados:
sns.boxplot(x='respuesta', y='resultado', data=bancoClean)
plt.title('Diferencia de saldo promedio anual entre clientes interesados y no interesados')
plt.show()

# %%
#Distribución de estado civil entre clientes interesados:
sns.countplot(x='respuesta', hue='estado_civil', data=bancoClean)
plt.title('Distribución de estado civil entre clientes interesados y no interesados')
plt.show()

# %%
#Distribución medio de contacto de los clientes interesados:
plt.figure(figsize=(10, 6))
sns.countplot(x='contacto', hue='respuesta', data=bancoClean)
plt.title('Distribución de medio de contacto entre clientes interesados')
plt.show()

# %%
#Tipo de ocupación de los clientes interesados:
sns.countplot(y='trabajo', hue='respuesta', data=bancoClean)
plt.title('Tipo de ocupación de los clientes interesados')
plt.show()

# %%
#Patrón temporal en los contactos que conducen a una mayor conversión de clientes:
sns.countplot(x='mes', hue='respuesta', data=bancoClean)
plt.title('Patrón temporal en los contactos que conducen a una mayor conversión')
plt.show()
